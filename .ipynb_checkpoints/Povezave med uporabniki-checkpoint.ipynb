# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ast
import warnings
import seaborn as sb
import networkx as nx
warnings.filterwarnings('ignore')
plt.style.use('fivethirtyeight')

# %%
users = pd.read_csv("podatki/users.csv", sep=",", dtype=object)
users = users[pd.notnull(users['id'])]
users
# Out:
#                      id                       location                 name  \
# 0              18710816  near Utah Ave & Lighthouse an       Robby Delaware
# 1             100345056  still ⬆️Block⤵️Corner⬇️street     #Ezekiel2517✨...
# 2             247165706                    Chicago, IL     B E C K S T E R✨
# 3             249538861                            NaN        Chris Osborne
# 4             449689677                            NaN       Рамзан Кадыров
# 5             471868887        Санкт-Петербург, Россия      Маргарита Саваж
# 6            1039581360                        Amerika           Dark Nally
# 7            1510488662                            USA          Laila Heats
# 8            1513801268                            USA              CC Jack
# 9            1517678892               Philadelphia, PA             Mr Moran
# 10           1518857420                            USA     Jonathon Norwood
# 11           1532863891                            ATL           Harper H21
# 12           1533813962                            USA          Lara Pretty
# 13           1584279696                    Chicago, IL       Jasiah Jenkins
# 14           1594887416                            USA       Jeremy Roberts
# 15           1612106972                            USA    Reuben Littlejohn
# 16           1617939218                            USA         Pauline Gunn
# 17           1620474397                            USA      Ramona Mcintosh
# 18           1623180199                            NaN      Jeffrey Kahunas
# 19           1627096807                    Chicago, IL          Jason Scott
# 20           1627699074                  United States       Sherman Cannon
# 21           1629828379                  New York, USA          Lovely Cass
# 22           1647045721                         Alaska               Carrie
# 23           1648012021                  United States       Anthony Nelson
# 24           1649144358                            NaN        Wesley Holmes
# 25           1649487510                            USA         Khloe Irving
# 26           1649967228                  United States            Nick Luna
# 27           1650681522                  United States       Messiah Haynes
# 28           1651692980                            USA         Thomas Lopez
# 29           1651693646                  United States  Cynthia Mary Hunter
# ..                  ...                            ...                  ...
# 363  725305686989656064                            NaN          Berlin Bote
# 364  719275152987594752                            NaN          Blacktivist
# 365          2401770593                 Moscow, Russia      Валерий Бреусов
# 366  759825020210253825                  United States      Chaotic Neutral
# 367  752863577770455040                            NaN        Maria Fischer
# 368  756553776291540992                            NaN           GEO Review
# 369          2588788573                         Москва     Лана Дель Роджер
# 370  703670485859614720                            NaN             InstVets
# 371  719281218965999616      Islamic States of America        Jihadist Wife
# 372          2589592793                            NaN        Джонни Морган
# 373  752973172438212609                            NaN          LGBT United
# 374           535690498                            NaN             LinaLuna
# 375  716919079597182976                            NaN         Lukas Rösler
# 376          3906961827                          Paris         Maxime Garon
# 377  763665363154399232                            NaN       darya medovaya
# 378          2533095573                            NaN         Барин-Модник
# 379  718340894529822720                            NaN      Matthias Berger
# 380          2545365862                            NaN             ОбниМаша
# 381  748464969008680963                  United States        $10 challenge
# 382  750345924061368321                            NaN        Peter Kistner
# 383  762948178178150400                            NaN    Русские в Америке
# 384  752791693381033984                            NaN       Ingrid Schulte
# 385  752859805937766400                            NaN     Katharina Sonder
# 386  752881760510287872                            NaN           Tina Kurtz
# 387  749990330267758593                  st/petersburg     timofey tsvetkov
# 388  703291385861033984                            NaN      Williams&Kalvin
# 389  703303258476036096                            NaN       Diana Williams
# 390  752849847124946944                            NaN     Joachim Buchwitz
# 391  750656345926410240                            NaN         Klara Sauber
# 392  749931338573250560                            NaN        Maria Neuberg
#
#     followers_count statuses_count                    time_zone verified lang  \
# 0               304          11484   Pacific Time (US & Canada)    false   en
# 1              1053          31858                          NaN    false   en
# 2               650           6742  Mountain Time (US & Canada)    false   en
# 3                44            843                          NaN    false   en
# 4             94773          10877                       Moscow    false   ru
# 5             23305          18401                    Volgograd    false   ru
# 6                22          22603                      Jakarta    false   id
# 7              3080           2228   Eastern Time (US & Canada)    false   en
# 8              2760           2100   Eastern Time (US & Canada)    false   en
# 9               879           2044   Eastern Time (US & Canada)    false   en
# 10              789           2002   Eastern Time (US & Canada)    false   en
# 11             1956           3300   Eastern Time (US & Canada)    false   en
# 12             1795           3342   Eastern Time (US & Canada)    false   en
# 13              728           1918   Eastern Time (US & Canada)    false   en
# 14              837           1573   Eastern Time (US & Canada)    false   en
# 15              738           1899   Eastern Time (US & Canada)    false   en
# 16              908           1906   Eastern Time (US & Canada)    false   en
# 17              877           1745   Eastern Time (US & Canada)    false   en
# 18             1565           2320   Pacific Time (US & Canada)    false   en
# 19              674           1818   Eastern Time (US & Canada)    false   en
# 20             2854          10203   Eastern Time (US & Canada)    false   en
# 21             2121           3831   Eastern Time (US & Canada)    false   en
# 22             2291           3222   Eastern Time (US & Canada)    false   en
# 23              853           1771   Eastern Time (US & Canada)    false   en
# 24             1519           1232   Pacific Time (US & Canada)    false   en
# 25              909           1935   Eastern Time (US & Canada)    false   en
# 26             1457           2100   Pacific Time (US & Canada)    false   en
# 27             2804           5554   Eastern Time (US & Canada)    false   en
# 28              456           1637   Eastern Time (US & Canada)    false   en
# 29              429           2759   Eastern Time (US & Canada)    false   en
# ..              ...            ...                          ...      ...  ...
# 363               8           6804                         Bern    false   de
# 364            2404            710   Pacific Time (US & Canada)    false   en
# 365              91           1078                         Baku    false   en
# 366               1             16                          NaN    false   en
# 367              17            217                       Berlin    false   de
# 368              37             16   Pacific Time (US & Canada)    false   en
# 369              98            999                       Moscow    false   ru
# 370            2618            184                          NaN    false   en
# 371            5081           1071   Pacific Time (US & Canada)    false   en
# 372              67            738                    Volgograd    false   ru
# 373             338            453                          NaN    false   en
# 374             785           9394                    Volgograd    false   ru
# 375            1217           1212                       Berlin    false   de
# 376              82           1024                        Paris    false   fr
# 377            3263            248   Pacific Time (US & Canada)    false   ru
# 378              74            862                    Volgograd    false   ru
# 379             980           1135                       Berlin    false   de
# 380             244           1291                    Volgograd    false   ru
# 381              30              4   Pacific Time (US & Canada)    false   en
# 382              52            248                       Berlin    false   de
# 383               5             13                          NaN    false   ru
# 384              10            244                       Berlin    false   de
# 385              26            393                       Berlin    false   de
# 386               7            134                         Bern    false   de
# 387            3216           2271                          NaN    false   en
# 388             740            326                          NaN    false   en
# 389            1973            170   Pacific Time (US & Canada)    false   en
# 390               1              5                       Berlin    false   de
# 391              25             11                         Bern    false   de
# 392               8             15                         Bern    false   de
#
#          screen_name                                        description  \
# 0      RobbyDelaware  I support the free movement of people, ideas a...
# 1        SCOTTGOHARD  CELEBRITY TRAINER ✨#424W147th✨ #CrossfitCoach ...
# 2        Beckster319  Rebecca Lynn Hirschfeld Actress.Model.Writer.A...
# 3      skatewake1994                                                NaN
# 4      KadirovRussia  Пародийный аккаунт. Озвучиваю то, что политика...
# 5        MargoSavazh                   Честь имею. Нагло врать не умею.
# 6          darknally                                  uptodate news!!!!
# 7          lagonehoe       How can you judge me when you don’t know me?
# 8       YouJustCtrlC  ProBlack | Stoner | even jesus was stoned befo...
# 9           MrMoraan  I'm getting too cool for this social media shi...
# 10      NoJonathonNo  Strive not to be a success but rather to be of...
# 11    CharlesJHarper                       if you don't like me-it's ok
# 12   PrettyLaraPlace  Bitter Clinger #USAFVet #NRA #2A #bluestarmom ...
# 13      BigBoyJasiah  Visionary..... don't put me in a box.... Enigm...
# 14    Jery_RobertsYo  I think we can all agree that the 3 most power...
# 15        LILJordamn    young nigga just trying to make# also do music#
# 16         PaulineTT  I be trying to chill, I swear do, because I lu...
# 17      RamonasNails  Mom, Global Nail Artist, Consultant, blah,blah...
# 18    JeffreyKahunas  Honor God & Jesus & Your Parents Country, GOP,...
# 19         JassScott  Bring the drama, playa. Give me all you got. M...
# 20        CannonSher  Education costs money.  But then so does ignor...
# 21        cassishere  Fun-loving conservative sharing the truth that...
# 22   CarrieThornthon  Conservative Christian Momma. Political junkie...
# 23    ImaPharrelFake  Here to state my point of view, make you laugh...
# 24    WesternWindWes  Stand with God, Family, Constitution & 2A. On ...
# 25         HiImKhloe  Running back and forth forever between grief a...
# 26        _NickLuna_  Christian, Dad, Husband, Conservative. Trolls ...
# 27   IlikeBIGbuttand  The only true wisdom is in knowing you know no...
# 28        staywoke88                                  Problem solver...
# 29    CynthiaMHunter  Christian Conservative #ProConstitution #2A #P...
# ..               ...                                                ...
# 363       BerlinBote                                                NaN
# 364     Blacktivists                Non-Governmental Organization (NGO)
# 365     briys_valera                 Любите душу, а не то, что снаружи.
# 366       ChaNeutral  What makes a man turn neutral... Lust for gold...
# 367  fischermaria933                                                NaN
# 368  GeoreviewEurope                                                NaN
# 369       gorelkinnn                          любитель всяких глупостей
# 370        inst_vets                                                NaN
# 371  Jihadist2ndWife  Wife of an ISIS terrorist. Enjoying submission...
# 372     Jorda_Morgan  У людей период сейчас такой...\nЛибо Есенин.\n...
# 373          LGBTuni  We speak for all fellow members of LGBT commun...
# 374        Lmarinays                                                НЛО
# 375     lukas_rosler                                                NaN
# 376      maximgaron1  Né à #Paris, je m'interesse des affaires étran...
# 377         mmmdarya                                                NaN
# 378      Moda_Barina                          Стильно, модно, молодежно
# 379      mtthsberger  Fauler Student, ich studiere Wirtschaftsinform...
# 380          mwiqcen              я не люблю обнимашки, не тискай меня!
# 381     PeeOnHillary  Print Hillary's face  Pee on it  Send us proof...
# 382     PeterKistner                                                NaN
# 383       RUS_IN_USA                                                NaN
# 384        schultei2  Ich glaube an Gerechtigkeit seit dem 22. Novem...
# 385  SonderKatharina                   Ich studiere BWL und mag reisen!
# 386   TinaTkurtz1222                                                NaN
# 387        TTsvetkov                                        упакуй луну
# 388  Williams8kalvin  Videoblog about social issues. Subscribe to ou...
# 389  Williams_Diana_                     American. Conservative. Woman.
# 390  JoachimBuchwitz                                                NaN
# 391     klara_sauber                                                NaN
# 392    MariaNeuberg1                                                NaN
#
#                          created_at favourites_count friends_count  \
# 0    Wed Jan 07 04:38:02 +0000 2009               17           670
# 1    Tue Dec 29 23:15:22 +0000 2009             2774          1055
# 2    Fri Feb 04 06:38:45 +0000 2011             7273           896
# 3    Wed Feb 09 07:38:44 +0000 2011              227           154
# 4    Thu Dec 29 11:31:09 +0000 2011                0             7
# 5    Mon Jan 23 10:26:25 +0000 2012             1480          8021
# 6    Thu Dec 27 13:06:58 +0000 2012                0            40
# 7    Wed Jun 12 13:07:49 +0000 2013             3504          2369
# 8    Thu Jun 13 16:07:23 +0000 2013             2744          2700
# 9    Fri Jun 14 21:58:48 +0000 2013             2981           758
# 10   Sat Jun 15 08:47:02 +0000 2013             2170           440
# 11   Thu Jun 20 04:49:04 +0000 2013             1850          1626
# 12   Thu Jun 20 12:35:59 +0000 2013             3555          1360
# 13   Wed Jul 10 23:55:16 +0000 2013             2342           393
# 14   Mon Jul 15 03:34:50 +0000 2013             1836           898
# 15   Mon Jul 22 05:34:20 +0000 2013             2251           608
# 16   Wed Jul 24 14:50:02 +0000 2013             1983          1075
# 17   Thu Jul 25 14:06:28 +0000 2013             1992          1138
# 18   Fri Jul 26 15:01:14 +0000 2013             1090          1586
# 19   Sun Jul 28 04:54:51 +0000 2013             2004           321
# 20   Sun Jul 28 11:51:53 +0000 2013            10128          2487
# 21   Mon Jul 29 07:59:27 +0000 2013             4154          2220
# 22   Mon Aug 05 05:56:27 +0000 2013             3930          2272
# 23   Mon Aug 05 14:58:13 +0000 2013             2764          1164
# 24   Tue Aug 06 01:49:24 +0000 2013              592          1351
# 25   Tue Aug 06 05:08:41 +0000 2013             2026           859
# 26   Tue Aug 06 10:16:28 +0000 2013             2001          1262
# 27   Tue Aug 06 16:32:34 +0000 2013             3939          2421
# 28   Wed Aug 07 01:19:25 +0000 2013             1117           551
# 29   Wed Aug 07 01:19:57 +0000 2013             4532           451
# ..                              ...              ...           ...
# 363  Wed Apr 27 12:48:46 +0000 2016                0             0
# 364  Sun Apr 10 21:25:34 +0000 2016               21          1424
# 365  Tue Mar 11 09:47:20 +0000 2014              498            53
# 366  Sun Jul 31 18:56:16 +0000 2016                0            55
# 367  Tue Jul 12 13:53:59 +0000 2016              135            75
# 368  Fri Jul 22 18:17:31 +0000 2016                3           281
# 369  Thu Jun 26 03:43:22 +0000 2014             2029           340
# 370  Sat Feb 27 19:58:12 +0000 2016                3          4244
# 371  Sun Apr 10 21:49:41 +0000 2016             1036          3797
# 372  Sat Jun 07 15:13:07 +0000 2014             1371           104
# 373  Tue Jul 12 21:09:28 +0000 2016                0           262
# 374  Sat Mar 24 20:41:43 +0000 2012              627           202
# 375  Mon Apr 04 09:23:23 +0000 2016             1270          3067
# 376  Fri Oct 09 07:46:20 +0000 2015               31           522
# 377  Thu Aug 11 09:16:25 +0000 2016              249           380
# 378  Tue May 06 15:30:14 +0000 2014             1594            52
# 379  Fri Apr 08 07:33:10 +0000 2016             2113          2966
# 380  Tue May 13 16:22:47 +0000 2014             2461           257
# 381  Thu Jun 30 10:35:29 +0000 2016                0          1510
# 382  Tue Jul 05 15:09:43 +0000 2016               32           632
# 383  Tue Aug 09 09:46:35 +0000 2016                0            18
# 384  Tue Jul 12 09:08:21 +0000 2016               71           100
# 385  Tue Jul 12 13:39:00 +0000 2016              108           210
# 386  Tue Jul 12 15:06:14 +0000 2016               77            55
# 387  Mon Jul 04 15:36:43 +0000 2016             2812           405
# 388  Fri Feb 26 18:51:47 +0000 2016               32           599
# 389  Fri Feb 26 19:38:58 +0000 2016                0          4468
# 390  Tue Jul 12 12:59:25 +0000 2016               13            50
# 391  Wed Jul 06 11:43:14 +0000 2016               12           192
# 392  Mon Jul 04 11:42:19 +0000 2016               11           100
#
#     listed_count
# 0             13
# 1             35
# 2             30
# 3              1
# 4            691
# 5            231
# 6             16
# 7             12
# 8             10
# 9             15
# 10             8
# 11            21
# 12            24
# 13            19
# 14             5
# 15            16
# 16             5
# 17             6
# 18            18
# 19            13
# 20            30
# 21            36
# 22            23
# 23            16
# 24            29
# 25            13
# 26            21
# 27            27
# 28            11
# 29            23
# ..           ...
# 363            7
# 364           36
# 365            0
# 366            0
# 367            1
# 368            0
# 369            1
# 370           13
# 371           51
# 372            0
# 373            3
# 374            3
# 375           14
# 376            1
# 377            0
# 378            0
# 379           23
# 380            3
# 381            0
# 382            2
# 383            2
# 384            2
# 385            1
# 386            0
# 387            0
# 388            9
# 389           10
# 390            0
# 391            0
# 392            0
#
# [393 rows x 14 columns]

# %%
sb.pairplot(users)

# %%
tweets_data = pd.read_csv("podatki/tweets.csv", dtype=object)

# %%
retweeted_status_ids = tweets_data['retweeted_status_id'].loc[pd.notnull(tweets_data['retweeted_status_id'])]
retweeted_df = tweets_data[pd.notnull(tweets_data['retweeted_status_id'])]

# %%
retweets = tweets_data['tweet_id'].loc[tweets_data['tweet_id'].isin(retweeted_status_ids)]
retweets_df = tweets_data[tweets_data['tweet_id'].isin(retweeted_status_ids)]

# %%
G = nx.Graph()
G.add_nodes_from(tweets_data[tweets_data['tweet_id'].isin(retweeted_status_ids)])
for i in retweeted_df.values:
    G.add_edge(i[8], i[14])

# %%
nx.draw_networkx(G, with_labels=False, node_size=10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/networkx/drawing/layout.py in fruchterman_reingold_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#     459                                            iterations, threshold,
# --> 460                                            dim, seed)
#     461     except:
#
# </usr/local/lib/python3.5/dist-packages/decorator.py:decorator-gen-795> in _sparse_fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, seed)
#
# /usr/local/lib/python3.5/dist-packages/networkx/utils/decorators.py in _random_state(func, *args, **kwargs)
#     404         new_args[random_state_index] = random_state
# --> 405         return func(*new_args, **kwargs)
#     406     return _random_state
#
# /usr/local/lib/python3.5/dist-packages/networkx/drawing/layout.py in _sparse_fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, seed)
#     602             displacement[:, i] +=\
# --> 603                 (delta * (k * k / distance**2 - Ai * distance / k)).sum(axis=1)
#     604         # update positions
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# MemoryError                               Traceback (most recent call last)
# <ipython-input-82-b44a377cde6e> in <module>
# ----> 1 nx.draw_networkx(G, with_labels=False, node_size=10)
#
# /usr/local/lib/python3.5/dist-packages/networkx/drawing/nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     275
#     276     if pos is None:
# --> 277         pos = nx.drawing.spring_layout(G)  # default to spring layout
#     278
#     279     node_collection = draw_networkx_nodes(G, pos, **kwds)
#
# </usr/local/lib/python3.5/dist-packages/decorator.py:decorator-gen-791> in fruchterman_reingold_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#
# /usr/local/lib/python3.5/dist-packages/networkx/utils/decorators.py in _random_state(func, *args, **kwargs)
#     403         new_args = list(args)
#     404         new_args[random_state_index] = random_state
# --> 405         return func(*new_args, **kwargs)
#     406     return _random_state
#     407
#
# /usr/local/lib/python3.5/dist-packages/networkx/drawing/layout.py in fruchterman_reingold_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#     460                                            dim, seed)
#     461     except:
# --> 462         A = nx.to_numpy_array(G, weight=weight)
#     463         if k is None and fixed is not None:
#     464             # We must adjust k by domain size for layouts not near 1x1
#
# /usr/local/lib/python3.5/dist-packages/networkx/convert_matrix.py in to_numpy_array(G, nodelist, dtype, order, multigraph_weight, weight, nonedge)
#    1117     else:
#    1118         # Graph or DiGraph, this is much faster than above
# -> 1119         A = np.full((nlen, nlen), np.nan, order=order)
#    1120         for u, nbrdict in G.adjacency():
#    1121             for v, d in nbrdict.items():
#
# ~/.local/lib/python3.5/site-packages/numpy/core/numeric.py in full(shape, fill_value, dtype, order)
#     307     if dtype is None:
#     308         dtype = array(fill_value).dtype
# --> 309     a = empty(shape, dtype, order)
#     310     multiarray.copyto(a, fill_value, casting='unsafe')
#     311     return a
#
# MemoryError:
